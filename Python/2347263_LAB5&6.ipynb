# %% [markdown]
# LAB 5 Excercise

# %% [markdown]
# Question 1

# %%
try:
    a=50
    b=78
    div=a/b
    print(f'The div is:{div}')
except ZeroDivisionError:
    print('Enter number greater than 0')
# Out:
# The div is:0.6410256410256411

# %% [markdown]
# Question 2

# %%
arr=[1,2,3,4,5,]

print(arr)
n = int(input("Enter the element you want to access:"))

try:
    print(arr[n])

except IndexError:
    print("!!!!INDEX ERROR")
# Out:
# [1, 2, 3, 4, 5]
# !!!!INDEX ERROR

# %% [markdown]
# Lab Excercise 6

# %% [markdown]
# Question 1

# %%
import re

def find_valid_phone_number(text):
    pattern = r'\d{10}'
    phone_numbers = re.findall(pattern, text)

    if phone_numbers:
        return phone_numbers[0]
    else:
        return "No valid phone number found"

n = input("Enter a text to search for an Indian phone number: ")
result = find_valid_phone_number(n)
print(result)
# Out:
# No valid phone number found

# %% [markdown]
# Question 2

# %%
import re

def is_strong_password(password):
    if len(password) < 8:
        return False

    if not re.search(r'[A-Z]', password):
        return False

    if not re.search(r'[a-z]', password):
        return False

    if not re.search(r'\d', password):
        return False

    if not re.search(r'[!@#$%^&*()_+{}\[\]:;<>,.?\\\/\-]', password):
        return False

    return True
password = input("Enter a password: ")
    
if is_strong_password(password):
     print("Password is strong.")
else:
   print("Password is not strong.")
# Out:
# Password is not strong.
